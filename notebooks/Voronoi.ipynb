# %%
import VoronoiGraph as vg
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
vor=vg.gen_voronoi(16)

# %%
G=vg.voronoi_graph(vor)
H=vg.voronoi_loopy_dual(vor)

# %%
G.number_of_edges()
# Out:
# 29

# %%
H.number_of_edges()
# Out:
# 29

# %%
nx.draw(G, pos={n:G.node[n]['pos'] for n in G.nodes()})
nx.draw(H, pos={n:H.node[n]['pos'] for n in H.nodes()}, node_color='g', edge_color='b')

# %%
H.number_of_nodes()==G.number_of_edges()-G.number_of_nodes()+1
# Out:
# True

# %%
G.number_of_edges()==H.number_of_edges()
# Out:
# True

# %%
vor.point_region
# Out:
# array([ 6, 13, 10, 16, 14, 11,  9,  4,  3,  1, 15,  8,  7,  2,  5, 12])
