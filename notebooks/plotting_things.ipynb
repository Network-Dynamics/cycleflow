# %%
import pickle

# %%
with open("../data/decay_diff_p_rewire_size_100.pickle", 'rb') as f:
    data2=pickle.load(f)

# %%
data2
# Out:
# [(0.9,
#   array([[  0.00000000e+00,   1.54683466e-01,   0.00000000e+00],
#        [  1.00000000e+00,  -5.66456680e-02,   1.32021192e-01],
#        [  2.00000000e+00,   4.82995413e-03,   5.75715808e-03],
#        [  3.00000000e+00,   1.57605769e-03,   2.05316324e-03],
#        [  4.00000000e+00,   3.89361850e-04,   5.81625622e-04],
#        [  5.00000000e+00,   1.26242310e-04,   1.84838600e-04],
#        [  6.00000000e+00,   4.04145692e-05,   4.78456304e-05],
#        [  7.00000000e+00,   2.69736065e-05,   2.10958422e-05],
#        [  8.00000000e+00,   1.91508102e-05,   1.17540041e-05],
#        [  9.00000000e+00,   9.49138989e-06,   6.03199827e-06],
#        [  1.00000000e+01,   4.96313771e-06,   3.11476233e-06],
#        [  1.10000000e+01,   3.33544535e-06,   2.15369184e-06],
#        [  1.20000000e+01,   2.11855278e-06,   1.57514714e-06],
#        [  1.30000000e+01,   1.17912535e-06,   1.05798616e-06],
#        [  1.40000000e+01,   8.74369366e-07,   8.39550265e-07],
# ...

# %%
data2.keys()
# Out:
# [0.5, 0.7, 0.9, 0.3]

# %%
data=data3

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
plt.tick_params(axis='both', which='major', labelsize=20)
plt.plot(data[0.0]['x']/np.max(data[0.0]['x']), np.abs(data[0.0]['y'])/np.max(np.abs(data[0.0]['y'])), 'bo-')
plt.xlabel(r"$d_c/max(d_c)$", fontsize=30, )
plt.ylabel(r"$\left\langle f_c \right\rangle/max(\left\langle f_c \right\rangle)$", fontsize=30)
plt.savefig("decay_sqgrid.pdf")

# %%
plt.tick_params(axis='both', which='major', labelsize=20)
plt.plot(np.log(data[0.0]['x']/np.max(data[0.0]['x'])), np.log(np.abs(data[0.0]['y'])/np.max(np.abs(data[0.0]['y']))), 'bo-')
plt.xlabel(r"$\log{\left[d_c/max(d_c)\right]}$", fontsize=30 )
plt.ylabel(r"$\log{\left[\left\langle f_c \right\rangle/max(\left\langle f_c \right\rangle)\right]}$", fontsize=30)
plt.savefig("decay_log_log_sqgrid.pdf")

# %%
plt.tick_params(axis='both', which='major', labelsize=20)
plt.plot(data[0]['x']/np.max(data[0]['x']), np.abs(data[0]['y'])/np.max(np.abs(data[0]['y'])), 'bo-', label="p=0")
plt.plot(data2[2][1][:,0]/np.max(data2[2][1][:,0]), np.abs(data2[2][1][:,1])/np.max(np.abs(data2[2][1][:,1])), 'go-', label="p=0.3")
plt.legend()
plt.xlabel(r"$d_c/max(d_c)$", fontsize=30, )
plt.ylabel(r"$\left\langle f_c \right\rangle/max(\left\langle f_c \right\rangle)$", fontsize=30)
plt.savefig("decay_sqgrid.pdf")

# %%
data.keys()
# Out:
# [0.5, 0.7, 0.9, 0.3]

# %%
plt.tick_params(axis='both', which='major', labelsize=20)
plt.plot(np.log(data[0.0]['x']/np.max(data[0.0]['x'])), np.log(np.abs(data[0.0]['y'])/np.max(np.abs(data[0.0]['y']))), 'bo-', label="p=0")
plt.plot(np.log(data2[2][1][:,0]/np.max(data2[2][1][:,0])), np.log(np.abs(data2[2][1][:,1])/np.max(np.abs(data2[2][1][:,1]))), 'go-', label="p=0.3")
plt.legend()
plt.xlabel(r"$\log{\left[d_c/max(d_c)\right]}$", fontsize=30 )
plt.ylabel(r"$\log{\left[\left\langle f_c \right\rangle/max(\left\langle f_c \right\rangle)\right]}$", fontsize=30)
plt.savefig("decay_log_log_sqgrid.pdf")

# %%
data2
# Out:
# {0.3: array([[  0.00000000e+00,   2.79071970e-01,   0.00000000e+00],
#        [  1.00000000e+00,  -8.13920448e-02,   1.26795310e-01],
#        [  2.00000000e+00,  -2.68818829e-02,   2.97642501e-02],
#        [  3.00000000e+00,  -1.35908374e-02,   1.13200585e-02],
#        [  4.00000000e+00,  -9.55535933e-03,   5.83379753e-03],
#        [  5.00000000e+00,  -7.02232216e-03,   3.60869085e-03],
#        [  6.00000000e+00,  -4.39884203e-03,   1.86636850e-03],
#        [  7.00000000e+00,  -3.14626492e-03,   1.26425330e-03],
#        [  8.00000000e+00,  -2.54302754e-03,   9.65575029e-04],
#        [  9.00000000e+00,  -1.67921153e-03,   7.00292317e-04],
#        [  1.00000000e+01,  -1.39632149e-03,   5.86564153e-04],
#        [  1.10000000e+01,  -1.22648710e-03,   4.71469511e-04],
#        [  1.20000000e+01,  -9.77835391e-04,   3.92637388e-04],
#        [  1.30000000e+01,  -8.40308536e-04,   2.97066540e-04],
#        [  1.40000000e+01,  -6.59351603e-04,   2.63599658e-04],
# ...
